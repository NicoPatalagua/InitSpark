# %% [markdown]
# <a href="https://colab.research.google.com/github/NicoPatalagua/Notebooks/blob/master/Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from datetime import datetime
from pyspark.sql.types import IntegerType, TimestampType, DoubleType
import os
import time 
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-2.4.5-bin-hadoop2.7"
from google.colab import drive
drive.mount('drive')
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("app")
sc = SparkContext.getOrCreate();

# %%
os.environ['PYSPARK_SUBMIT_ARGS'] = '--packages org.apache.spark:spark-avro_2.12:2.4.2 pyspark-shell'

# %%
sc = SparkContext()

# %%
spark = SparkSession(sc).builder.getOrCreate()

# %%
path_input = "C:/MS/bonzk_datio_30752_sas_aml_anps/amlEmployees/src/test/resources/data/inputs/t_ptyc_employees/cutoff_date=2021-06-21/"

# %%
rba_df = spark.read.format("avro").load(path_input)

# %%
rba_df.show(3000, False)
# Out:
# +---------+----------------------+-----------+------------------------+-----------------+--------------------------+-----------------------+------------+-------------------+---------------------------+-----------------------+-------------+-----------------------------+
# |entity_id|original_risk_model_id|customer_id|rating_calif_occr_number|rating_model_type|rating_econ_sector_tmpl_id|cst_study_month_year_id|company_type|restriction_type_id|cst_restriction_calc_amount|last_modify_record_date|user_audit_id|operational_audit_insert_date|
# +---------+----------------------+-----------+------------------------+-----------------+--------------------------+-----------------------+------------+-------------------+---------------------------+-----------------------+-------------+-----------------------------+
# ...

# %%
output_path = "C:/Users/alvaro.nicolas.pata1/Desktop/Ingestions/"

# %%
rba_df.repartition(1).write.mode("overwrite").csv(output_path + "rba.csv", sep=";", header=True)

# %%
#rba_df.select("operational_audit_insert_date", "rba_score_date").head()
